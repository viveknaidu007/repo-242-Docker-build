# %%
#for building the project
docker build -t <image_name_any_name>

# %%
#for running the project , give new container name
docker run -d --name <running_container_any_name> -p 8080:8080 <image_name_which_created>

# %%
#checking logs :
docker logs -f <running_container_Name>

# %%
#for checking status:
docker ps

# %%
#stopping contianer:
docker stop <running_container_name>

# %%
#for removing the runinng contianer:
docker rm -f <container_name>
